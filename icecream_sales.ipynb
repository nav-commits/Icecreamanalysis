# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
# Load the dataset
file_path = 'icecream_sales.csv'
df = pd.read_csv(file_path)

# %%
# Display the DataFrame
print(df)
# Out:
#    Temperature  Sales
# 0           25    100
# 1           28    120
# 2           22     80
# 3           30    150
# 4           26    110
# 5           24     95
# 6           29    130

# %%
cleaned_data = df.dropna()

# %%
# mean for tempature
mean_temperature = np.mean(cleaned_data['Temperature'])

# %%
# median for sales
median_sales = np.median(cleaned_data['Sales'])

# %%
print(median_sales, mean_temperature)
# Out:
# 110.0 26.285714285714285

# %%
X = cleaned_data[['Temperature']]  # Predictor variable
y = cleaned_data['Sales']          # Response variable

# %%
print(X,y)
# Out:
#    Temperature
# 0           25
# 1           28
# 2           22
# 3           30
# 4           26
# 5           24
# 6           29 0    100
# 1    120
# 2     80
# 3    150
# 4    110
# 5     95
# 6    130
# Name: Sales, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
model = LinearRegression()
model.fit(X_train, y_train)
model.predict(X_test)

# Predicting the Test set results
y_pred = model.predict(X_test)

# Evaluating the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mse, r2
# Out:
# (35.20455558858498, 0.943672711058264)

# %%
# Scatter plot of the data
plt.scatter(X, y, color='blue', label='Actual Sales')

# Plotting the regression line
line = model.coef_ * X + model.intercept_
plt.plot(X, line, color='red', label='Regression Line')

# Adding title and labels
plt.title('Ice Cream Sales vs Temperature')
plt.xlabel('Temperature')
plt.ylabel('Sales')
plt.legend()

# Show plot
plt.show()

# %%
# make predction for 15 degrees
temp_to_predict = [[15]]
predicted_sales = model.predict(temp_to_predict)

predicted_sales[0]
# Out:
# /Users/biomacbook/Documents/miniconda3/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 12.5
